# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.2.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
# Downloading pyahocorasick-2.2.0-cp313-cp313-win_amd64.whl (35 kB)
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
#
#    ---------------------------------------- 0/4 [pyahocorasick]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    -------------------- ------------------- 2/4 [textsearch]
#    -------------------- ------------------- 2/4 [textsearch]
#    -------------------- ------------------- 2/4 [textsearch]
#    ------------------------------ --------- 3/4 [contractions]
#    ------------------------------ --------- 3/4 [contractions]
#    ---------------------------------------- 4/4 [contractions]
#
# Successfully installed anyascii-0.3.3 contractions-0.1.73 pyahocorasick-2.2.0 textsearch-0.0.24
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %unzip /usr/share/nltk_data/corpora/wordnet.zip -d /usr/share/nltk_data/corpora/
# Out:
# UsageError: Line magic function `%unzip` not found.

# %%
# %pip install yellowbrick nltk tensorflow keras
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting keras
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from yellowbrick) (3.10.6)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from yellowbrick) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from yellowbrick) (1.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from yellowbrick) (2.2.6)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from yellowbrick) (0.12.1)
# Collecting click (from nltk)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from nltk) (1.5.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from nltk) (4.67.1)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\leoni\appdata\roaming\python\python313\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\leoni\appdata\roaming\python\python313\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.15.1-cp313-cp313-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in c:\users\leoni\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting rich (from keras)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras)
#   Downloading optree-0.18.0-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: colorama in c:\users\leoni\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from rich->keras) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 7.9 MB/s  0:00:00
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#     --------------------------------------- 7.3/332.0 MB 35.7 MB/s eta 0:00:10
#    - -------------------------------------- 13.9/332.0 MB 33.2 MB/s eta 0:00:10
#    -- ------------------------------------- 21.0/332.0 MB 32.3 MB/s eta 0:00:10
#    --- ------------------------------------ 25.2/332.0 MB 29.0 MB/s eta 0:00:11
#    --- ------------------------------------ 29.6/332.0 MB 27.7 MB/s eta 0:00:11
#    ---- ----------------------------------- 35.1/332.0 MB 27.4 MB/s eta 0:00:11
#    ---- ----------------------------------- 39.6/332.0 MB 26.2 MB/s eta 0:00:12
#    ----- ---------------------------------- 48.8/332.0 MB 28.6 MB/s eta 0:00:10
#    ------ --------------------------------- 54.0/332.0 MB 28.2 MB/s eta 0:00:10
#    ------- -------------------------------- 60.8/332.0 MB 28.4 MB/s eta 0:00:10
#    ------- -------------------------------- 65.8/332.0 MB 28.2 MB/s eta 0:00:10
#    -------- ------------------------------- 68.2/332.0 MB 27.8 MB/s eta 0:00:10
#    --------- ------------------------------ 77.1/332.0 MB 27.8 MB/s eta 0:00:10
#    --------- ------------------------------ 82.8/332.0 MB 27.9 MB/s eta 0:00:09
#    ---------- ----------------------------- 87.8/332.0 MB 28.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 94.4/332.0 MB 27.9 MB/s eta 0:00:09
#    ------------ --------------------------- 99.9/332.0 MB 27.7 MB/s eta 0:00:09
#    ------------ -------------------------- 105.9/332.0 MB 27.9 MB/s eta 0:00:09
#    ------------- ------------------------- 111.1/332.0 MB 27.5 MB/s eta 0:00:09
#    ------------- ------------------------- 116.1/332.0 MB 27.3 MB/s eta 0:00:08
#    -------------- ------------------------ 121.1/332.0 MB 27.2 MB/s eta 0:00:08
#    -------------- ------------------------ 125.6/332.0 MB 26.8 MB/s eta 0:00:08
#    --------------- ----------------------- 131.1/332.0 MB 26.7 MB/s eta 0:00:08
#    --------------- ----------------------- 134.5/332.0 MB 26.6 MB/s eta 0:00:08
#    ---------------- ---------------------- 140.8/332.0 MB 26.4 MB/s eta 0:00:08
#    ---------------- ---------------------- 144.4/332.0 MB 26.1 MB/s eta 0:00:08
#    ----------------- --------------------- 148.4/332.0 MB 25.9 MB/s eta 0:00:08
#    ------------------ -------------------- 156.2/332.0 MB 26.1 MB/s eta 0:00:07
#    ------------------ -------------------- 161.0/332.0 MB 25.9 MB/s eta 0:00:07
#    ------------------- ------------------- 165.2/332.0 MB 25.8 MB/s eta 0:00:07

#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    - --------------------------------------  1/28 [libclang]
#    -- -------------------------------------  2/28 [flatbuffers]
#    -- -------------------------------------  2/28 [flatbuffers]
#    -- -------------------------------------  2/28 [flatbuffers]
#    -- -------------------------------------  2/28 [flatbuffers]
#    -- -------------------------------------  2/28 [flatbuffers]
#    ---- -----------------------------------  3/28 [wrapt]
#    ---- -----------------------------------  3/28 [wrapt]
#    ---- -----------------------------------  3/28 [wrapt]
#    ---- -----------------------------------  3/28 [wrapt]
#    ---- -----------------------------------  3/28 [wrapt]
#    ---- -----------------------------------  3/28 [wrapt]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ----- ----------------------------------  4/28 [werkzeug]
#    ------- --------------------------------  5/28 [termcolor]
#    ------- --------------------------------  5/28 [termcolor]
#    ------- --------------------------------  5/28 [termcolor]
#    ------- --------------------------------  5/28 [termcolor]
#    ------- --------------------------------  5/28 [termcolor]
#    -------- -------------------------------  6/28 [tensorboard-data-server]
#    -------- -------------------------------  6/28 [tensorboard-data-server]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ---------- -----------------------------  7/28 [regex]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ----------- ----------------------------  8/28 [protobuf]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    ------------ ---------------------------  9/28 [optree]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    -------------- ------------------------- 10/28 [opt_einsum]
#    --------------- ------------------------ 11/28 [ml_dtypes]
#    ----------------- ---------------------- 12/28 [mdurl]
#    ----------------- ---------------------- 12/28 [mdurl]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    ------------------ --------------------- 13/28 [markdown]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    -------------------- ------------------- 14/28 [h5py]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    --------------------- ------------------ 15/28 [grpcio]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ---------------------- ----------------- 16/28 [google_pasta]
#    ------------------------ --------------- 17/28 [gast]
#    ------------------------ --------------- 17/28 [gast]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    ------------------------- -------------- 18/28 [click]
#    --------------------------- ------------ 19/28 [astunparse]
#    --------------------------- ------------ 19/28 [astunparse]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ---------------------------- ----------- 20/28 [absl-py]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------ --------- 21/28 [tensorboard]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
#    ------------------------------- -------- 22/28 [nltk]
# ...
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    -------------------------------------- - 27/28 [tensorflow]
#    ---------------------------------------- 28/28 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 click-8.3.1 flatbuffers-25.9.23 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.12.0 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 nltk-3.9.2 opt_einsum-3.4.0 optree-0.18.0 protobuf-6.33.1 regex-2025.11.3 rich-14.2.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 werkzeug-3.1.3 wrapt-2.0.1 yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wordcloud keras
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: keras in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (3.12.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in c:\users\leoni\appdata\roaming\python\python313\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in c:\users\leoni\appdata\roaming\python\python313\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: absl-py in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: rich in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\leoni\appdata\roaming\python\python313\site-packages (from keras) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\leoni\.conda\envs\iotdocker1\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#----------SKLEARN--------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV


from sklearn.cluster import KMeans , AgglomerativeClustering, DBSCAN
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer,ClusteringScoreVisualizer
from sklearn.metrics import silhouette_score


#-------NLTK--------------
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from unidecode import unidecode
from contractions import fix
from nltk.util import ngrams

from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from wordcloud import WordCloud

#-------TENSORFLOW---------
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Input, SimpleRNN, LSTM , GRU, Bidirectional, Embedding
from keras.layers import Dropout

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore')

# %%
# %pip install pytesseract
# Out:
# Collecting pytesseract
#   Using cached pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\leoni\appdata\roaming\python\python313\site-packages (from pytesseract) (11.3.0)
# Using cached pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

import pytesseract
import re

from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 11
#       8 from sklearn.linear_model import SGDClassifier
#       9 from sklearn.svm import SVC
# ---> 11 from xgboost import XGBClassifier
#      12 from catboost import CatBoostClassifier
#      13 from lightgbm import LGBMClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %% [markdown]
# ## E-Mail Document

# %%
path = r"datasets\document-classification-dataset\email\doc_000042.png"
image = Image.open(path)
image

# %% [markdown]
# ## Resume

# %%
path = r"datasets\document-classification-dataset\resume\doc_000051.png"
image = Image.open(path)
image

# %% [markdown]
# ## Scientific Publication

# %%
path = r"datasets\document-classification-dataset\scientific_publication\doc_000016.png"
image = Image.open(path)
image

# %%
text = pytesseract.image_to_string(image)
text

# %%
stopwords_list = stopwords.words("english")
#stopwords_list

# %% [markdown]
# ## Data Preprocessing

# %%
def preprocess_data(text):
    text = text.lower()
    text = text.replace("\n"," ").replace("\t"," ")
    text = re.sub("\s+"," ",text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    
    # tokens
    tokens = word_tokenize(text)
    
    data = [i for i in tokens if i not in punctuation]
    data = [i for i in data if i not in stopwords_list]
    
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    final_text = []
    for i in data:
        word = lemmatizer.lemmatize(i)
        final_text.append(word)
        
    return " ".join(final_text)

#preprocess_data(text)

# %%
import os

class_labels = {'email':0,'resume':1,'scientific_publication':2}

final_text = []
final_label = []
path = r"datasets\document-classification-dataset"
image_folder = os.listdir(path)

for label in image_folder:
        #print(label)
        label_path = os.path.join(path,label)
        for j in os.listdir(label_path):
            #print(j)
            image = Image.open(label_path+"/"+j)
            #print(image)
            text = pytesseract.image_to_string(image)
            text_data = preprocess_data(text)
            
            final_text.append(text_data)
            final_label.append(class_labels[label])

# %%
df = pd.DataFrame()
df['Text'] = final_text
df['Label'] = final_label
df

# %%
df.iloc[110]

# %%
df['Text'][110]

# %% [markdown]
# ## Target Labels Analysis

# %%
df['Label'].value_counts()

# %%
df['Label'].value_counts().plot(kind='pie',autopct="%.1f%%")
plt.title("Document Distributions")
plt.legend()
plt.show()

# %%
sns.countplot(x=df['Label'])
plt.title("Document Distributions")
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,auc,roc_curve,precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %% [markdown]
# ## Split The Data

# %%
x_train,x_test,y_train,y_test = train_test_split(df['Text'],df['Label'],shuffle=True,test_size=0.10)
print(x_train.shape)
print(x_test.shape)

# %%
x_train

# %%
y_train

# %% [markdown]
# ## TfidfVectorizer

# %%
tfidf = TfidfVectorizer(ngram_range=(2,5), max_df=0.95, min_df=2 ,max_features=10000)
tfidf_train = tfidf.fit_transform(x_train)
tfidf_test = tfidf.transform(x_test)

# %%
tfidf_train.A.shape

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### LogisticRegression

# %%
model = LogisticRegression()
model.fit(tfidf_train.A,y_train)

# %%
y_pred = model.predict(tfidf_test.A)
y_pred

# %%
y_pred_tr = model.predict(tfidf_train.A)
y_pred_tr

# %% [markdown]
# ## Model Evaluation

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print()
print("Classification Report:\n",classification_report(y_test,y_pred))

# %%
print("Confusion Matrix:\n",confusion_matrix(y_train,y_pred_tr))
print()
print("Classification Report:\n",classification_report(y_train,y_pred_tr))

# %%
print(f"Accuracy on Test Data: {accuracy_score(y_test,y_pred)*100:.2f} %")
print(f"Accuracy on Train Data: {accuracy_score(y_train,y_pred_tr)*100:.2f} %")

# %% [markdown]
# ### LogisticRegression

# %%
lg_model = LogisticRegression(max_iter=2000,solver='liblinear',C=100)
lg_model.fit(tfidf_train.A,y_train)

# %%
y_pred = lg_model.predict(tfidf_test.A)
y_pred

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print()
print("Classification Report:\n",classification_report(y_test,y_pred))

# %%
print(f"Accuracy on Test Data: {accuracy_score(y_test,y_pred)*100:.2f} %")

# %%
y_test.values

# %% [markdown]
# ## Pickle File For Deployment

# %%
import pickle
import json

# %%
class_labels

# %%
# Class_labels
label_data = ['email', 'resume' ,'scientific_publication']

# %%
with open("model.pickle","wb") as file:
    pickle.dump(model,file)

# %%
with open("tfidf.pickle","wb") as file1:
    pickle.dump(tfidf,file1)

# %%
with open("new_model.pickle","wb") as file2:
    pickle.dump(lg_model,file2)
